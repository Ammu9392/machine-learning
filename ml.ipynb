# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammu9392/machine-learning/blob/main/ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("/content/housing.csv")
data
# Out:
#         RM  LSTAT  PTRATIO    MEDV
# 0    6.575   4.98     15.3  504000
# 1    6.421   9.14     17.8  453600
# 2    7.185   4.03     17.8  728700
# 3    6.998   2.94     18.7  701400
# 4    7.147   5.33     18.7  760200
# ..     ...    ...      ...     ...
# 484  6.593   9.67     21.0  470400
# 485  6.120   9.08     21.0  432600
# 486  6.976   5.64     21.0  501900
# 487  6.794   6.48     21.0  462000
# 488  6.030   7.88     21.0  249900
#
# [489 rows x 4 columns]

# %%
data.isnull()
# Out:
#         RM  LSTAT  PTRATIO   MEDV
# 0    False  False    False  False
# 1    False  False    False  False
# 2    False  False    False  False
# 3    False  False    False  False
# 4    False  False    False  False
# ..     ...    ...      ...    ...
# 484  False  False    False  False
# 485  False  False    False  False
# 486  False  False    False  False
# 487  False  False    False  False
# 488  False  False    False  False
#
# [489 rows x 4 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mms=MinMaxScaler()

# %%
data=mms.fit_transform(data)

# %%
data=pd.DataFrame(data)

# %%
data
# Out:
#             0         1         2         3
# 0    0.623114  0.083356  0.287234  0.433790
# 1    0.591276  0.198944  0.553191  0.378995
# 2    0.749225  0.056960  0.553191  0.678082
# 3    0.710564  0.026674  0.648936  0.648402
# 4    0.741369  0.093081  0.648936  0.712329
# ..        ...       ...       ...       ...
# 484  0.626835  0.213670  0.893617  0.397260
# 485  0.529047  0.197277  0.893617  0.356164
# 486  0.706016  0.101695  0.893617  0.431507
# 487  0.668389  0.125035  0.893617  0.388128
# 488  0.510440  0.163934  0.893617  0.157534
#
# [489 rows x 4 columns]

# %%
 from sklearn.model_selection import train_test_split

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
x
# Out:
#             0         1         2
# 0    0.623114  0.083356  0.287234
# 1    0.591276  0.198944  0.553191
# 2    0.749225  0.056960  0.553191
# 3    0.710564  0.026674  0.648936
# 4    0.741369  0.093081  0.648936
# ..        ...       ...       ...
# 484  0.626835  0.213670  0.893617
# 485  0.529047  0.197277  0.893617
# 486  0.706016  0.101695  0.893617
# 487  0.668389  0.125035  0.893617
# 488  0.510440  0.163934  0.893617
#
# [489 rows x 3 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.metrics import confusion_matrix

# %%
r2_score(y_test,pred)
# Out:
# 0.6574622113312862

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred=dtr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pred)
# Out:
# 0.6897939068952293

# %%
from sklearn.decomposition import PCA

# %%
pip install nltk

# %%
import nltk

# %%
from nltk.stem import PorterStemmer

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk.corpus import stopwords

# %%
text="Computational linguistics is the science of understanding and constructing human language models with computers and software tools. Researchers use computational linguistics methods, such as syntactic and semantic analysis, to create frameworks that help machines understand conversational human language. Tools like language translators, text-to-speech synthesizers, and speech recognition software are based on computational linguistics. "

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

# %%
def tokenize(text):
  tokens=word_tokenize(text.lower())
  print(tokens)
tokenize(text)
# Out:
# ['computational', 'linguistics', 'is', 'the', 'science', 'of', 'understanding', 'and', 'constructing', 'human', 'language', 'models', 'with', 'computers', 'and', 'software', 'tools', '.', 'researchers', 'use', 'computational', 'linguistics', 'methods', ',', 'such', 'as', 'syntactic', 'and', 'semantic', 'analysis', ',', 'to', 'create', 'frameworks', 'that', 'help', 'machines', 'understand', 'conversational', 'human', 'language', '.', 'tools', 'like', 'language', 'translators', ',', 'text-to-speech', 'synthesizers', ',', 'and', 'speech', 'recognition', 'software', 'are', 'based', 'on', 'computational', 'linguistics', '.']

# %%
porter=PorterStemmer()

# %%
stem_words=p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4ef679716da3> in <cell line: 1>()
# ----> 1 stopword=set(stopword)
#
# NameError: name 'stopword' is not defined
